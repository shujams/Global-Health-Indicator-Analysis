# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load (Remember to Change These)
data_to_load = "Resource/data.csv"

# Read the Mouse and Drug Data and the Clinical Trial Data
health_data_pd = pd.read_csv(data_to_load)

# Display the data table for preview
health_data_pd
# Out:
#       Country Name Country Code  \
# 0       Arab World          ARB
# 1       Arab World          ARB
# 2       Arab World          ARB
# 3       Arab World          ARB
# 4       Arab World          ARB
# ...            ...          ...
# 89005     Zimbabwe          ZWE
# 89006     Zimbabwe          ZWE
# 89007     Zimbabwe          ZWE
# 89008     Zimbabwe          ZWE
# 89009     Zimbabwe          ZWE
#
#                                           Indicator Name     Indicator Code  \
# 0      % of females ages 15-49 having comprehensive c...  SH.HIV.KNOW.FE.ZS
# 1      % of males ages 15-49 having comprehensive cor...  SH.HIV.KNOW.MA.ZS
# 2      Adolescent fertility rate (births per 1,000 wo...        SP.ADO.TFRT
# 3      Adults (ages 15+) and children (0-14 years) li...        SH.HIV.TOTL
# 4      Adults (ages 15+) and children (ages 0-14) new...     SH.HIV.INCD.TL
# ...                                                  ...                ...
# 89005  Use of insecticide-treated bed nets (% of unde...     SH.MLR.NETS.ZS
# 89006  Use of Intermittent Preventive Treatment of ma...     SH.MLR.SPF2.ZS
# 89007  Vitamin A supplementation coverage rate (% of ...     SN.ITK.VITA.ZS
# 89008           Wanted fertility rate (births per woman)        SP.DYN.WFRT
# 89009  Women's share of population ages 15+ living wi...  SH.DYN.AIDS.FE.ZS
#
#              1960        1961        1962        1963        1964        1965  \
# 0             NaN         NaN         NaN         NaN         NaN         NaN
# 1             NaN         NaN         NaN         NaN         NaN         NaN
# 2      133.555013  134.159119  134.857912  134.504576  134.105211  133.569626
# 3             NaN         NaN         NaN         NaN         NaN         NaN
# 4             NaN         NaN         NaN         NaN         NaN         NaN
# ...           ...         ...         ...         ...         ...         ...
# 89005         NaN         NaN         NaN         NaN         NaN         NaN
# 89006         NaN         NaN         NaN         NaN         NaN         NaN
# 89007         NaN         NaN         NaN         NaN         NaN         NaN
# 89008         NaN         NaN         NaN         NaN         NaN         NaN
# 89009         NaN         NaN         NaN         NaN         NaN         NaN
#
#        ...       2007       2008       2009       2010       2011       2012  \
# 0      ...        NaN        NaN        NaN        NaN        NaN        NaN
# 1      ...        NaN        NaN        NaN        NaN        NaN        NaN
# 2      ...  49.999851  49.887046  49.781207  49.672975  49.536047  49.383745
# 3      ...        NaN        NaN        NaN        NaN        NaN        NaN
# 4      ...        NaN        NaN        NaN        NaN        NaN        NaN
# ...    ...        ...        ...        ...        ...        ...        ...
# 89005  ...        NaN        NaN  17.300000        NaN   9.700000        NaN
# 89006  ...        NaN        NaN  13.900000        NaN   7.300000        NaN
# 89007  ...  83.000000   0.000000  77.000000  49.000000  47.000000  61.000000
# 89008  ...        NaN        NaN        NaN        NaN   3.500000        NaN
# 89009  ...  58.586086  58.760796  58.812421  58.825943  58.899308  58.939080
#
#             2013       2014       2015  Unnamed: 60
# 0            NaN        NaN        NaN          NaN
# 1            NaN        NaN        NaN          NaN
# 2      48.796558  48.196418        NaN          NaN
# 3            NaN        NaN        NaN          NaN
# 4            NaN        NaN        NaN          NaN
# ...          ...        ...        ...          ...
# 89005        NaN  26.800000        NaN          NaN
# 89006        NaN  12.900000        NaN          NaN
# 89007  34.000000  32.000000        NaN          NaN
# 89008        NaN        NaN        NaN          NaN
# 89009  58.900126  58.822335  58.855551          NaN
#
# [89010 rows x 61 columns]

# %%
health_data_decade_df = health_data_pd[['Country Name','Country Code','Indicator Name','Indicator Code','2005','2006','2007','2008','2009','2010','2011','2012','2013','2014','2015']]
health_data_decade_df


# health_data_decade_pd = health_data_pd.loc[:,'2005':'2015']
# health_data_decade_pd
# Out:
#       Country Name Country Code  \
# 0       Arab World          ARB
# 1       Arab World          ARB
# 2       Arab World          ARB
# 3       Arab World          ARB
# 4       Arab World          ARB
# ...            ...          ...
# 89005     Zimbabwe          ZWE
# 89006     Zimbabwe          ZWE
# 89007     Zimbabwe          ZWE
# 89008     Zimbabwe          ZWE
# 89009     Zimbabwe          ZWE
#
#                                           Indicator Name     Indicator Code  \
# 0      % of females ages 15-49 having comprehensive c...  SH.HIV.KNOW.FE.ZS
# 1      % of males ages 15-49 having comprehensive cor...  SH.HIV.KNOW.MA.ZS
# 2      Adolescent fertility rate (births per 1,000 wo...        SP.ADO.TFRT
# 3      Adults (ages 15+) and children (0-14 years) li...        SH.HIV.TOTL
# 4      Adults (ages 15+) and children (ages 0-14) new...     SH.HIV.INCD.TL
# ...                                                  ...                ...
# 89005  Use of insecticide-treated bed nets (% of unde...     SH.MLR.NETS.ZS
# 89006  Use of Intermittent Preventive Treatment of ma...     SH.MLR.SPF2.ZS
# 89007  Vitamin A supplementation coverage rate (% of ...     SN.ITK.VITA.ZS
# 89008           Wanted fertility rate (births per woman)        SP.DYN.WFRT
# 89009  Women's share of population ages 15+ living wi...  SH.DYN.AIDS.FE.ZS
#
#             2005       2006       2007       2008       2009       2010  \
# 0            NaN        NaN        NaN        NaN        NaN        NaN
# 1            NaN        NaN        NaN        NaN        NaN        NaN
# 2      50.732590  50.329135  49.999851  49.887046  49.781207  49.672975
# 3            NaN        NaN        NaN        NaN        NaN        NaN
# 4            NaN        NaN        NaN        NaN        NaN        NaN
# ...          ...        ...        ...        ...        ...        ...
# 89005        NaN   3.100000        NaN        NaN  17.300000        NaN
# 89006        NaN   6.300000        NaN        NaN  13.900000        NaN
# 89007  81.000000  67.000000  83.000000   0.000000  77.000000  49.000000
# 89008        NaN   3.300000        NaN        NaN        NaN        NaN
# 89009  58.045596  58.331272  58.586086  58.760796  58.812421  58.825943
#
#             2011       2012       2013       2014       2015
# 0            NaN        NaN        NaN        NaN        NaN
# 1            NaN        NaN        NaN        NaN        NaN
# 2      49.536047  49.383745  48.796558  48.196418        NaN
# 3            NaN        NaN        NaN        NaN        NaN
# 4            NaN        NaN        NaN        NaN        NaN
# ...          ...        ...        ...        ...        ...
# 89005   9.700000        NaN        NaN  26.800000        NaN
# 89006   7.300000        NaN        NaN  12.900000        NaN
# 89007  47.000000  61.000000  34.000000  32.000000        NaN
# 89008   3.500000        NaN        NaN        NaN        NaN
# 89009  58.899308  58.939080  58.900126  58.822335  58.855551
#
# [89010 rows x 15 columns]

# %%
countries_sorted_df = health_data_decade_df.groupby('Country Name')
countries_sorted_df
usa_df = countries_sorted_df.get_group('United States') 
usa_df
# Out:
#         Country Name Country Code  \
# 85215  United States          USA
# 85216  United States          USA
# 85217  United States          USA
# 85218  United States          USA
# 85219  United States          USA
# ...              ...          ...
# 85555  United States          USA
# 85556  United States          USA
# 85557  United States          USA
# 85558  United States          USA
# 85559  United States          USA
#
#                                           Indicator Name     Indicator Code  \
# 85215  % of females ages 15-49 having comprehensive c...  SH.HIV.KNOW.FE.ZS
# 85216  % of males ages 15-49 having comprehensive cor...  SH.HIV.KNOW.MA.ZS
# 85217  Adolescent fertility rate (births per 1,000 wo...        SP.ADO.TFRT
# 85218  Adults (ages 15+) and children (0-14 years) li...        SH.HIV.TOTL
# 85219  Adults (ages 15+) and children (ages 0-14) new...     SH.HIV.INCD.TL
# ...                                                  ...                ...
# 85555  Use of insecticide-treated bed nets (% of unde...     SH.MLR.NETS.ZS
# 85556  Use of Intermittent Preventive Treatment of ma...     SH.MLR.SPF2.ZS
# 85557  Vitamin A supplementation coverage rate (% of ...     SN.ITK.VITA.ZS
# 85558           Wanted fertility rate (births per woman)        SP.DYN.WFRT
# 85559  Women's share of population ages 15+ living wi...  SH.DYN.AIDS.FE.ZS
#
#           2005     2006    2007     2008     2009     2010     2011    2012  \
# 85215      NaN      NaN     NaN      NaN      NaN      NaN      NaN     NaN
# 85216      NaN      NaN     NaN      NaN      NaN      NaN      NaN     NaN
# 85217  41.0818  40.3754  39.669  37.7398  35.8106  33.8814  31.9522  30.023
# 85218      NaN      NaN     NaN      NaN      NaN      NaN      NaN     NaN
# 85219      NaN      NaN     NaN      NaN      NaN      NaN      NaN     NaN
# ...        ...      ...     ...      ...      ...      ...      ...     ...
# 85555      NaN      NaN     NaN      NaN      NaN      NaN      NaN     NaN
# 85556      NaN      NaN     NaN      NaN      NaN      NaN      NaN     NaN
# 85557      NaN      NaN     NaN      NaN      NaN      NaN      NaN     NaN
# 85558      NaN      NaN     NaN      NaN      NaN      NaN      NaN     NaN
# 85559      NaN      NaN     NaN      NaN      NaN      NaN      NaN     NaN
#
#           2013     2014  2015
# 85215      NaN      NaN   NaN
# 85216      NaN      NaN   NaN
# 85217  27.0666  24.1102   NaN
# 85218      NaN      NaN   NaN
# 85219      NaN      NaN   NaN
# ...        ...      ...   ...
# 85555      NaN      NaN   NaN
# 85556      NaN      NaN   NaN
# 85557      NaN      NaN   NaN
# 85558      NaN      NaN   NaN
# 85559      NaN      NaN   NaN
#
# [345 rows x 15 columns]

# %%
dropped_usa_df = usa_df.dropna() 
dropped_usa_df

dropped_usa_df.set_index("Indicator Code", inplace=True)
#dropped_usa_df

dropped_usa_data_df = dropped_usa_df.loc[['SH.IMM.HEPB', 'SH.IMM.MEAS', 'SH.STA.ACSN','SP.DYN.IMRT.IN','SH.H2O.SAFE.ZS','SP.POP.GROW','SP.POP.TOTL']]
dropped_usa_data_df
dropped_usa_data_df_format = dropped_usa_data_df

#dropped_usa_df.to_csv('dropped_usa.csv')
dropped_usa_data_df_format["2005"] = dropped_usa_data_df["2005"].map("{:,.2f}".format)
dropped_usa_data_df_format["2006"] = dropped_usa_data_df["2006"].map("{:,.2f}".format)
dropped_usa_data_df_format["2007"] = dropped_usa_data_df["2007"].map("{:,.2f}".format)
dropped_usa_data_df_format["2008"] = dropped_usa_data_df["2008"].map("{:,.2f}".format)
dropped_usa_data_df_format["2009"] = dropped_usa_data_df["2009"].map("{:,.2f}".format)
dropped_usa_data_df_format["2010"] = dropped_usa_data_df["2010"].map("{:,.2f}".format)
dropped_usa_data_df_format["2011"] = dropped_usa_data_df["2011"].map("{:,.2f}".format)
dropped_usa_data_df_format["2012"] = dropped_usa_data_df["2012"].map("{:,.2f}".format)
dropped_usa_data_df_format["2013"] = dropped_usa_data_df["2013"].map("{:,.2f}".format)
dropped_usa_data_df_format["2014"] = dropped_usa_data_df["2014"].map("{:,.2f}".format)
dropped_usa_data_df_format["2015"] = dropped_usa_data_df["2015"].map("{:,.2f}".format)

dropped_usa_data_df_format
# Out:
#                  Country Name Country Code  \
# Indicator Code
# SH.IMM.HEPB     United States          USA
# SH.IMM.MEAS     United States          USA
# SH.STA.ACSN     United States          USA
# SP.DYN.IMRT.IN  United States          USA
# SH.H2O.SAFE.ZS  United States          USA
# SP.POP.GROW     United States          USA
# SP.POP.TOTL     United States          USA
#
#                                                    Indicator Name  \
# Indicator Code
# SH.IMM.HEPB      Immunization, HepB3 (% of one-year-old children)
# SH.IMM.MEAS     Immunization, measles (% of children ages 12-2...
# SH.STA.ACSN     Improved sanitation facilities (% of populatio...
# SP.DYN.IMRT.IN     Mortality rate, infant (per 1,000 live births)
# SH.H2O.SAFE.ZS  Improved water source (% of population with ac...
# SP.POP.GROW                          Population growth (annual %)
# SP.POP.TOTL                                     Population, total
#
#                           2005            2006            2007  \
# Indicator Code
# SH.IMM.HEPB              93.00           93.00           93.00
# SH.IMM.MEAS              92.00           92.00           92.00
# SH.STA.ACSN              99.80           99.90           99.90
# SP.DYN.IMRT.IN            6.80            6.70            6.60
# SH.H2O.SAFE.ZS           99.00           99.00           99.00
# SP.POP.GROW               0.92            0.96            0.95
# SP.POP.TOTL     295,516,599.00  298,379,912.00  301,231,207.00
#
#                           2008            2009            2010  \
# Indicator Code
# SH.IMM.HEPB              94.00           92.00           92.00
# SH.IMM.MEAS              92.00           90.00           92.00
# SH.STA.ACSN              99.90           99.90           99.90
# SP.DYN.IMRT.IN            6.50            6.40            6.30
# SH.H2O.SAFE.ZS           99.00           99.10           99.10
# SP.POP.GROW               0.95            0.88            0.84
# SP.POP.TOTL     304,093,966.00  306,771,529.00  309,346,863.00
#
#                           2011            2012            2013  \
# Indicator Code
# SH.IMM.HEPB              91.00           90.00           91.00
# SH.IMM.MEAS              92.00           91.00           92.00
# SH.STA.ACSN             100.00          100.00          100.00
# SP.DYN.IMRT.IN            6.10            6.10            5.90
# SH.H2O.SAFE.ZS           99.10           99.10           99.20
# SP.POP.GROW               0.76            0.76            0.74
# SP.POP.TOTL     311,718,857.00  314,102,623.00  316,427,395.00
#
#                           2014            2015
# Indicator Code
# SH.IMM.HEPB              92.00           92.00
# SH.IMM.MEAS              92.00           92.00
# SH.STA.ACSN             100.00          100.00
# SP.DYN.IMRT.IN            5.70            5.60
# SH.H2O.SAFE.ZS           99.20           99.20
# SP.POP.GROW               0.78            0.78
# SP.POP.TOTL     318,907,401.00  321,418,820.00

# %%
dropped_usa_data_df_format.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', '2005', '2006',
#        '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015'],
#       dtype='object')

# %%
mortality_rates = dropped_usa_data_df_format[dropped_usa_data_df_format["Indicator Name"] == "Mortality rate, infant (per 1,000 live births)"]
mortality_rates
# Out:
#                  Country Name Country Code  \
# Indicator Code
# SP.DYN.IMRT.IN  United States          USA
#
#                                                 Indicator Name  2005  2006  \
# Indicator Code
# SP.DYN.IMRT.IN  Mortality rate, infant (per 1,000 live births)  6.80  6.70
#
#                 2007  2008  2009  2010  2011  2012  2013  2014  2015
# Indicator Code
# SP.DYN.IMRT.IN  6.60  6.50  6.40  6.30  6.10  6.10  5.90  5.70  5.60

# %%
mortality_rates_usa = (mortality_rates.iloc[:,3:])
mortality_rates_usa
# Out:
#                 2005  2006  2007  2008  2009  2010  2011  2012  2013  2014  \
# Indicator Code
# SP.DYN.IMRT.IN  6.80  6.70  6.60  6.50  6.40  6.30  6.10  6.10  5.90  5.70
#
#                 2015
# Indicator Code
# SP.DYN.IMRT.IN  5.60

# %%
HepB3_rates = dropped_usa_data_df_format[dropped_usa_data_df_format["Indicator Name"] == "Immunization, HepB3 (% of one-year-old children)"].iloc[:,3:]
HepB3_rates
# Out:
#                  2005   2006   2007   2008   2009   2010   2011   2012   2013  \
# Indicator Code
# SH.IMM.HEPB     93.00  93.00  93.00  94.00  92.00  92.00  91.00  90.00  91.00
#
#                  2014   2015
# Indicator Code
# SH.IMM.HEPB     92.00  92.00

# %%
yr_list
# Out:
# [2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015]

# %%
HepB3_rates
# Out:
#                  2005   2006   2007   2008   2009   2010   2011   2012   2013  \
# Indicator Code
# SH.IMM.HEPB     93.00  93.00  93.00  94.00  92.00  92.00  91.00  90.00  91.00
#
#                  2014   2015
# Indicator Code
# SH.IMM.HEPB     92.00  92.00

# %%
list(HepB3_rates.iloc[0, :])
# Out:
# ['93.00',
#  '93.00',
#  '93.00',
#  '94.00',
#  '92.00',
#  '92.00',
#  '91.00',
#  '90.00',
#  '91.00',
#  '92.00',
#  '92.00']

# %%
HepB3_rates.iloc[0, :]
# Out:
# 2005    93.00
# 2006    93.00
# 2007    93.00
# 2008    94.00
# 2009    92.00
# 2010    92.00
# 2011    91.00
# 2012    90.00
# 2013    91.00
# 2014    92.00
# 2015    92.00
# Name: SH.IMM.HEPB, dtype: object

# %%
type(HepB3_rates.iloc[0, :])
# Out:
# pandas.core.series.Series

# %%
yr_list= ['2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015']

yr_list = [int(x) for x in yr_list]

plt.plot(yr_list, HepB3_rates.iloc[0, :])
plt.plot(yr_list, mortality_rates_usa.iloc[0, :])

# %%
plt.scatter(HepB3_rates.iloc[0, :], mortality_rates_usa.iloc[0, :])

# %%
HepB3_rates.columns
# Out:
# Index(['2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015'],
#       dtype='object')
